# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def show(name, n, m, i, title):
    image = mpimg.imread(name)
    plt.subplot(n, m, i)
    plt.imshow(image, cmap='gray')
    plt.title(title)
    plt.axis('off')

show('task1.jpeg', 1, 1, 1, 'Task 1')
plt.show()
